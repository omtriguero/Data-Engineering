# %% [markdown]
# <a href="https://colab.research.google.com/github/omtriguero/Data-Engineering/blob/main/TP1/Data_Engineering_Final_Project_(hotel_reservations).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **FINAL PROJECT-CDBM-602-001 Data Engineerings.**
#
# *   Oscar Mauricio Trigueros

# %% [markdown]
# Follow this step-by-step guide to work on your project (Total 30 marks)

# %% [markdown]
# **Step 1: Select a real-world dataset**
#
# >•Find a one of the interesting datasetes:
#
# World University Rankings: https://www.kaggle.com/mylesoneill/world-university-rankings

# %% [markdown]
#  >•The data should be in CSV format, and should contain at least 4 columns and 200 rows

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn import linear_model
import numpy as np

# %%
df_ru = pd.read_csv("hotel_bookings.csv")
print(df_ru)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# **Step 2: Perform data preparation & cleaning (7 marks)**

# %% [markdown]
# •	Load the dataset into a data frame using Pandas

# %%
df_ru.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
pd.DataFrame(df_ru)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# •	Explore the number of rows & columns, ranges of values etc.

# %%
df_ru.shape # numbers of columns and rows
# Out:
# (119390, 29)

# %%
df_ru.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
type(df_ru)
# Out:
# pandas.core.frame.DataFrame

# %%
df_ru.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# agent                              16340
# company                           112593
# ...

# %%
df_ru.isnull().any()
# Out:
# hotel                             False
# is_canceled                       False
# lead_time                         False
# arrival_date_year                 False
# arrival_date_month                False
# arrival_date_week_number          False
# arrival_date_day_of_month         False
# stays_in_weekend_nights           False
# stays_in_week_nights              False
# adults                            False
# children                           True
# babies                            False
# market_segment                    False
# distribution_channel              False
# is_repeated_guest                 False
# previous_cancellations            False
# previous_bookings_not_canceled    False
# reserved_room_type                False
# assigned_room_type                False
# booking_changes                   False
# deposit_type                      False
# agent                              True
# company                            True
# ...

# %%
df_ru.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# •	Handle missing, incorrect and invalid data

# %%
df_ru['agent'] = df_ru['agent'].fillna(df_ru['agent'].mean())

# %%
df_ru['children'] = df_ru['children'].fillna(df_ru['children'].mean())

# %%
df_ru['company'] = df_ru['company'].fillna(df_ru['company'].mean())

# %%
print(df_ru)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# •	Perform any additional steps (parsing dates, creating additional columns, merging multiple datasets etc.)

# %% [markdown]
# **Step 3: Perform exploratory analysis & visualization (7 marks)**

# %% [markdown]
# •	Compute the mean, sum, range and other interesting statistics for numeric columns

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['total_of_special_requests']].agg(['min', 'max','mean','std',range]))
# Out:
#        total_of_special_requests
# min                     0.000000
# max                     5.000000
# mean                    0.571363
# std                     0.792798
# range                   5.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['days_in_waiting_list']].agg(['min', 'max','mean','std',range]))
# Out:
#        days_in_waiting_list
# min                0.000000
# max              391.000000
# mean               2.321149
# std               17.594721
# range            391.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['is_canceled']].agg(['min', 'max','mean','std',range]))
# Out:
#        is_canceled
# min       0.000000
# max       1.000000
# mean      0.370416
# std       0.482918
# range     1.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['lead_time']].agg(['min', 'max','mean','std',range]))
# Out:
#         lead_time
# min      0.000000
# max    737.000000
# mean   104.011416
# std    106.863097
# range  737.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['arrival_date_year']].agg(['min', 'max','mean','std',range]))
# Out:
#        arrival_date_year
# min          2015.000000
# max          2017.000000
# mean         2016.156554
# std             0.707476
# range           2.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['arrival_date_week_number']].agg(['min', 'max','mean','std',range]))
# Out:
#        arrival_date_week_number
# min                    1.000000
# max                   53.000000
# mean                  27.165173
# std                   13.605138
# range                 52.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['arrival_date_day_of_month']].agg(['min', 'max','mean','std',range]))
# Out:
#        arrival_date_day_of_month
# min                     1.000000
# max                    31.000000
# mean                   15.798241
# std                     8.780829
# range                  30.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['stays_in_weekend_nights']].agg(['min', 'max','mean','std',range]))
# Out:
#        stays_in_weekend_nights
# min                   0.000000
# max                  19.000000
# mean                  0.927599
# std                   0.998613
# range                19.000000

# %%
def range(series):
 return series.max()-series.min()

print(df_ru[['year']].agg(['min', 'max','mean','std',range]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-115-26793b8621e2> in <cell line: 4>()
#       2  return series.max()-series.min()
#       3
# ----> 4 print(df_ru[['year']].agg(['min', 'max','mean','std',range]))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
# ...

# %%
sb.pairplot(df_ru)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-116-f1453b1a7113> in <cell line: 1>()
# ----> 1 sb.pairplot(df_ru)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2172         grid.add_legend()
#    2173
# -> 2174     grid.tight_layout()
#    2175
#    2176     return grid
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in tight_layout(self, *args, **kwargs)
#     116         if self._tight_layout_pad is not None:
#     117             kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118         self._figure.tight_layout(*args, **kwargs)
#     119         return self
#     120
#
# ...

# %%
df_ru.columns = ['world_rank',	'university_name',	'country' ,	'teaching',	'international' ,	'research','citations',	'income',	'total_score' ,	'num_students' ,	'international_students' ,	'year']

df_ru.index = df_ru.world_rank

researchtop = df_ru['research']

researchtop.plot(kind='hist')

researchtop.plot()

# %%
univ_subset = df_ru[['world_rank',	'university_name']]
print(univ_subset)
